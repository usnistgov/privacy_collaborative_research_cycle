# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Authors:
# - [Karan Bhagat](mailto:kb.in.triangulum@gmail.com) - Developer
# - [Christine Task](mailto:christine.task@knexusresearch.com) - Project technical lead
# - [Dhruv Kapur](mailto:dhruvka@umich.edu) - Contributor

# %% [markdown]
# ## NIST Collaborative Research Cycle (CRC)
# ### Example Notebook 3: Race Distribution (difference in count of records of each race in deid dataset and target dataset).
#
# One concern with data deidentification is the difficulty of maintaining accurate data distributions on data with diverse subpopulations. Privacy algorithms tend to reduce the visibility of outliers-- either intentionally, through Statistical Disclosure Limitation suppression schemes such as k-anonymity, or indirectly, through additive noise that has a relatively bigger impact on small counts (ie, a count of 2 +/- 2 retains less information than a count of 200 +/- 2).  When a diverse subpopulation has a smaller number of individuals, and those individuals have feature combinations that differ from the majority, that group can be dispersed more thinly across the feature space and then become significantly altered or erased during deidentification.
#
# In this notebook we show how to check in on this potential problem for our deidentified data samples, using a simple metric that compares the edit distance between the race distribution in the target data and deidentified data (using the csv data files for each). At the end of the notebook we print a data frame containing this metric and other algorithm properties that may be worthy of further exploration.
#
# #### List of topics covered in this notebook:
# 0. [Setup notebook.](#nb3-section-0)
# 1. [Load deid datasets index file (index.csv).](#nb3-section-1)
# <!--    1.1 [List properties (columns) of each deid. dataset (each row) in the index dataframe (created from index.csv).](#section-1.1)  -->
# 2. [CCompute difference in densities of each race between deid and target datasets.](#nb3-section-2)

# %% [markdown]
# <a id="nb3-section-0"></a>
# ## Setup notebook.

# %% [markdown]
# ### Import required libraries

# %%
# import required libraries
from pathlib import Path  # for creating paths for the filesystem operations
import os  # for filesystem operations
import pandas as pd  # for tabular data operations
import numpy as np  # for tabular data operations
import matplotlib.pyplot as plt  # for plotting data as charts
import json

# %% [markdown]
# ### Import local libraries present in libs package

# %%
# Import helper constants and functions
# libs.util has some small utility functions
# such has read_json, list_report etc.
import libs.util as u
# libs.plot module contains some helper
# funtions to create matplotlib charts
import libs.plot as plot
# libs.strs contains some constant strings
# represeting columns/feature names in index.csv file,
# report.json file, etc.
# Some examples of such constants: 
# LIBRARY_NAME, ALOGIRTHM_NAME, TARGET_DATASETetc.
from libs.strs import *
# lib.strs provides get_colors function that can be
# use to generate N random colors.
import libs.color as color

# %% [markdown]
# ### Change Current Working Directory (CWD) to: crc_data_and_metric_bundle

# %%
print('CWD Before: ', Path.cwd())
# get current working directory
cwd = Path.cwd()
# get path to the directory where is notebook is located
notebook_dir = u.notebook_path()
# Name of the parent directory of this notebook is crc_data_and_metric_bundle_1.0
new_cwd = notebook_dir.parent
# Set new current working directory path which ends in crc_data_and_metric_bundle_1.0
os.chdir(new_cwd)
print('CWD After: ', Path.cwd())
# Out:
# CWD Before:  /Users/karan/Documents/Knexus/NIST/SDNist/crc_acceleration_bundle_1.1/crc_data_and_metric_bundle_1.1
# CWD After:  /Users/karan/Documents/Knexus/NIST/SDNist/crc_acceleration_bundle_1.1/crc_data_and_metric_bundle_1.1

# %% [markdown]
# <a id="nb3-section-1"></a>
# ## 1. Load deid datasets index file (index.csv)
# index.csv file has tabular information about the deidentified (deid) datasets created using different data-deidentification libraries and algorithms.
# #### Location of index.csv: *crc_data_and_metric_bundle_1.0/index.csv*
# #### Location of this notebook: *crc_data_and_metric_bundle_1.0/notebooks/intro.ipynb*

# %%
CWD = Path.cwd()  # get current working directory path
# Create path to the index.csv file
INDEX_FILE_PATH = Path(CWD, 'index.csv')
# read index csv into idx_df variable
# idx stands for index
idx_df = pd.read_csv(INDEX_FILE_PATH, index_col=0).reset_index(drop=True)

# %% [markdown]
# Index data has a total of 298 different deid. datasets and each dataset has 23 different properties.

# %%
# See the shape of the index dataframe.
idx_df.shape
# Out:
# (324, 22)

# %%
# See five random rows of the index dataframe
idx_df.sample(5)
# Out:
#          library name algorithm name  algorithm type target dataset  \
# 138  smartnoise-synth            mst      stat model   national2019
# 213  smartnoise-synth      patectgan      neural net         tx2019
# 92                sdv          ctgan      neural net   national2019
# 49          rsynthpop            ipf  query matching   national2019
# 14         Genetic SD     Genetic SD  query matching         tx2019
#
#         feature set name           feature space size  \
# 138     industry-focused                    108108000
# 213      simple-features         14711336640000000000
# 92          all-features  517839049728000000000000000
# 49   demographic-focused                    227026800
# 14          all-features   36042774768000000000000000
#
#                                          features list privacy category  \
# 138  PUMA, SEX, MSP, HISP, RAC1P, OWN_RENT, INDP_CA...               dp
# 213  PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, H...               dp
# 92   PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, H...           non_dp
# 49   AGEP, SEX, MSP, RAC1P, HOUSING_TYPE, OWN_RENT,...               dp
# 14   PUMA, AGEP, SEX, MSP, HISP, RAC1P, NOC, NPF, H...               dp
#
#                                   privacy label detail  epsilon  ...  \
# 138  Differentially private synthetic data.  From M...      1.0  ...
# 213  Conditional tabular GAN using Private Aggregat...      1.0  ...
# 92   The CTGAN Synthesizer uses GAN-based, deep lea...      NaN  ...
# 49                               differential privacy       1.0  ...
# 14   Our submission satisfies approximate different...     10.0  ...
#
#     variant label detail                             research papers  \
# 138                  NaN   https://doi.org/10.48550/arXiv.2108.04978
# 213                  NaN  https://openreview.net/forum?id=S1zk9iRqF7
# 92                   NaN   https://doi.org/10.48550/arXiv.1907.00503
# 49                   NaN   https://doi.org/10.48550/arXiv.2206.01362
# 14                   NaN   https://doi.org/10.48550/arXiv.2306.03257
#
#                                              data path  \
# 138  deid_data/smartnoise_mst/national/mst_e_1_indu...
# 213  deid_data/smartnoise_patectgan/tx/patectgan_e_...
# 92   deid_data/sdv_ctgan/national/ctgan_0_AnnElliot...
# 49   deid_data/rsynthpop_ipf_Rsynthpop-categorical/...
# 14   deid_data/genetic_sd_DataEvolution/tx/genetic_...
#
#                                            labels path  \
# 138  deid_data/smartnoise_mst/national/mst_e_1_indu...
# 213  deid_data/smartnoise_patectgan/tx/patectgan_e_...
# 92   deid_data/sdv_ctgan/national/ctgan_0_AnnElliot...
# 49   deid_data/rsynthpop_ipf_Rsynthpop-categorical/...
# 14   deid_data/genetic_sd_DataEvolution/tx/genetic_...
#
#                                            report path                   team  \
# 138  deid_data/smartnoise_mst/national/report_mst_e...                    CRC
# 213  deid_data/smartnoise_patectgan/tx/report_patec...                    CRC
# 92   deid_data/sdv_ctgan/national/report_ctgan_0_An...                    CRC
# 49   deid_data/rsynthpop_ipf_Rsynthpop-categorical/...  Rsynthpop-categorical
# 14   deid_data/genetic_sd_DataEvolution/tx/report_g...          DataEvolution
#
#     submission number submission timestamp  quasi identifiers subset  \
# 138               NaN   5/20/2023 00:00:00                       NaN
# 213               NaN   5/20/2023 00:00:00                       NaN
# 92                NaN   5/20/2023 00:00:00                       NaN
# 49                2.0    5/8/2023 11:31:23                       NaN
# 14                2.0   4/16/2023 20:31:04                       NaN
#
#                                  deid data id
# 138  7a502dfb87d78a96e4e50122e70a6322ff4ea6bd
# 213  06e8de7b0a5cdef6e79c276f96f59f5ac6f08dfc
# 92   53aa64508e00d84f10e652d3a324e43b7b9704f0
# 49   659b0ca059cff98d4107c5843744344520da0960
# 14   48c09037b0e8ef4df01aad96394d95d4267652b6
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1.1 Veiw available features in the index dataframe.
# List features(columns) of each deid. dataset (each row) in the index dataframe (created from index.csv).
#
# Some features inform about the method of data synthesis (features such as 'library', 'algorithm name', 'epsilon', 'variant label' etc.) and others about the location of resources (such as 'data path' path to deid dataset csv file,
# 'report path' path to sdnist evaluation report of the deid dataset file etc.)

# %%
# Iterate over the columns of index dataframe
# and print each column name
for col in idx_df.columns:
    print(col)
# Out:
# library name
# algorithm name
# algorithm type
# target dataset
# feature set name
# feature space size
# features list
# privacy category
# privacy label detail
# epsilon
# delta
# variant label
# variant label detail
# research papers
# data path
# labels path
# report path
# team
# submission number
# submission timestamp
# quasi identifiers subset
# deid data id

# %%
# Use index_feature_description function from the libs.util module.
# index_feature_description function takes just one argument which 
# should be one of the column name available in the index file. 
# Column names are printed in the last code cell for your reference.
u.index_feature_description(LIBRARY_NAME)
# Out:
# Index Column:
# -------------
# library name
#
#
# Description:
# -----------
# Software library used for this submission, or team name if a private codebase was used

# %% [markdown]
# <a id="nb3-section-2"></a>
# ## 2. Compute difference in densities percentage of each race between deid and target datasets.
# Race density is computed by finding the fraction of people of a race in a dataset. We find race density percentage for both a deid dataset and its target dataset, and then take the absolute difference of these density percentages.
# We then use the absolute difference of density percentages to create a new score called race_edit_distance_percent.

# %%
# Store path to the target dataset base directory which is 
# diverse_communities_data_excerpts.
TARGET_DATA_DIR = Path(CWD, 'diverse_communities_data_excerpts')
# Store path to all the three datasets: ma2019, tx2019, and national2019
MA_PATH = Path(TARGET_DATA_DIR, 'massachusetts', 'ma2019.csv')
TX_PATH = Path(TARGET_DATA_DIR, 'texas', 'tx2019.csv')
NAT_PATH = Path(TARGET_DATA_DIR, 'national', 'national2019.csv')


# Declare constants that we use as
# column names
DEID_COUNT = 'deid_count'
DEID_DENSITY_PERCENT = 'deid_density_percent'
TARGET_COUNT = 'target_count'
TARGET_DENSITY_PERCENT = 'target_density_percent'
DIFFERENCE = 'difference'
RACE_EDIT_DISTANCE_PERCENT = 'race_edit_distance_percent'


# Create a new zero filled column
idx_df[RACE_EDIT_DISTANCE_PERCENT] = np.zeros(idx_df.shape[0]).astype(int)

# Iterate over each row (deid dataset) in index dataframe.
for i, row in idx_df.iterrows():
    # Get path of deid. data csv file
    data_path = row[DATA_PATH]
    # Read the csv file into a pandas dataframe using data path.
    data_deid_df = pd.read_csv(data_path)
    # Cleaning step (removes extra leading column from csv).
    data_deid_df = data_deid_df.loc[:, ~data_deid_df.columns.str.startswith('Unnamed')]
    data_deid_df = data_deid_df.reset_index(drop=True)
    
    # Get path to the target dataset from which the
    # current deid dataset is created
    target_dataset_name = row[TARGET_DATASET]
    target_path = ''
    
    if target_dataset_name == MA2019:
        target_path = MA_PATH
    elif target_dataset_name == TX2019:
        target_path = TX_PATH
    elif target_dataset_name == NATIONAL2019:
        target_path = NAT_PATH
    
    data_target_df = pd.read_csv(target_path)
    
    
    # Get count of each race in deid dataset and save it as new dataframe
    deid_race_df = data_deid_df[RAC1P].value_counts().to_frame(DEID_COUNT)
    # Compute density percent of each race in the deid dataset
    deid_race_df[DEID_DENSITY_PERCENT] = deid_race_df[DEID_COUNT] / data_deid_df.shape[0] * 100
    
    # Get count of each race in target dataset and save it as new dataframe
    target_race_df = data_target_df[RAC1P].value_counts().to_frame(TARGET_COUNT)
    # Compute density percent of each race in the target dataset
    target_race_df[TARGET_DENSITY_PERCENT] = target_race_df[TARGET_COUNT] / data_target_df.shape[0] * 100
    
    # Move unique values of RAC1P to a new column named RAC1P and set type as
    # 'int'. We change type to 'int' because some deid dataset save RAC1P
    # value as floats.
    deid_race_df[RAC1P] = deid_race_df.index.astype(int)
    target_race_df[RAC1P] = target_race_df.index.astype(int)
    
    # Sort deid and target dataset by race
    deid_race_df = deid_race_df.sort_values(by=RAC1P)
    target_race_df = target_race_df.sort_values(by=RAC1P)
    
    # Merge both dataset on RAC1P and do outer merge to take RAC1P values from
    # both deid and target dataset
    merged_df = target_race_df.merge(deid_race_df, on=RAC1P, how='outer')
    
    # Since few races can be missing in the deid dataset, those
    # will have nan values for deid_counts and deid_density_percent
    # columns after the merge operation
    merged_df = merged_df.fillna(0)
    # Get absolute difference of density percentages between target and deid dataset
    merged_df[DIFFERENCE] = abs(merged_df[DEID_DENSITY_PERCENT] - merged_df[TARGET_DENSITY_PERCENT])
        
    # Calculate edit distance between density percentages of races in 
    # target data and count of races in deid data
    edit_distance = sum(merged_df[DIFFERENCE].values)

    # Save value race values difference in
    # index dataframe.
    idx_df.loc[i, RACE_EDIT_DISTANCE_PERCENT] = round(edit_distance, 2)

# %% [markdown]
# ### 2.1 Worst performing 75 samples.

# %%
# See the random 100 records from index dataframe and
# the new column race_edit_distance which we just added to the
# index dataframe

# Set pandas display max rows option to display more
# dataframe rows in the cell output
pd.set_option('display.max_rows', 151)
# Name of the columns to display in the selected data samples
columns_to_show = [LIBRARY_NAME, ALGORITHM_NAME, ALGORITHM_TYPE, TARGET_DATASET,
                   PRIVACY_CATEGORY, EPSILON, FEATURE_SET_NAME, RACE_EDIT_DISTANCE_PERCENT]

# Sort the samples by race_edit_distance
idx_df = idx_df.sort_values(by=RACE_EDIT_DISTANCE_PERCENT, ascending=False)
# Show 75  worst performing samples in the index dataframe
idx_sample_df = idx_df[columns_to_show].head(75)
# Show samples dataframe
idx_sample_df
# Out:
#          library name   algorithm name  algorithm type target dataset  \
# 263         synthcity            dpgan      neural net   national2019
# 192  smartnoise-synth        patectgan      neural net         ma2019
# 209  smartnoise-synth        patectgan      neural net         tx2019
# 213  smartnoise-synth        patectgan      neural net         tx2019
# 191  smartnoise-synth        patectgan      neural net         ma2019
# 183  smartnoise-synth        patectgan      neural net         ma2019
# 188  smartnoise-synth        patectgan      neural net         ma2019
# 204  smartnoise-synth        patectgan      neural net         tx2019
# 212  smartnoise-synth        patectgan      neural net         tx2019
# 299         synthcity        privbayes      stat model   national2019
# 105               sdv  gaussian-copula      stat model   national2019
# 296         synthcity        privbayes      stat model   national2019
# 297         synthcity        privbayes      stat model   national2019
# 320            tumult           DPHist       histogram   national2019
# 201  smartnoise-synth        patectgan      neural net   national2019
# 289         synthcity        privbayes      stat model         ma2019
# 321            tumult           DPHist       histogram   national2019
# 47          rsynthpop           catall       histogram   national2019
# 42          rsynthpop           catall       histogram   national2019
# 61           sdcmicro       kanonymity             sdc   national2019
# 245         synthcity           adsgan      neural net   national2019
# 85                sdv       copula-gan      neural net         ma2019
# 269         synthcity          pategan      neural net         ma2019
# 246         synthcity           adsgan      neural net   national2019
# 170  smartnoise-synth         pacsynth  query matching   national2019
# 203  smartnoise-synth        patectgan      neural net         tx2019
# 62           sdcmicro       kanonymity             sdc   national2019
# 168  smartnoise-synth         pacsynth  query matching   national2019
# 291         synthcity        privbayes      stat model         ma2019
# 322            tumult           DPHist       histogram   national2019
# 194  smartnoise-synth        patectgan      neural net   national2019
# 171  smartnoise-synth         pacsynth  query matching   national2019
# 293         synthcity        privbayes      stat model         ma2019
# 276         synthcity          pategan      neural net   national2019
# 295         synthcity        privbayes      stat model   national2019
# 174  smartnoise-synth         pacsynth  query matching   national2019
# 305         synthcity        privbayes      stat model         tx2019
# 182  smartnoise-synth        patectgan      neural net         ma2019
# 104               sdv  gaussian-copula      stat model   national2019
# 242         synthcity           adsgan      neural net   national2019
# 275         synthcity          pategan      neural net   national2019
# 66           sdcmicro       kanonymity             sdc   national2019
# 266         synthcity          pategan      neural net         ma2019
# 69           sdcmicro       kanonymity             sdc         tx2019
# 72           sdcmicro       kanonymity             sdc         tx2019
# 180  smartnoise-synth         pacsynth  query matching         tx2019
# 178  smartnoise-synth         pacsynth  query matching         tx2019
# 271         synthcity          pategan      neural net         ma2019
# 110               sdv             tvae      neural net   national2019
# 177  smartnoise-synth         pacsynth  query matching         tx2019
# 282         synthcity          pategan      neural net         tx2019
# 197  smartnoise-synth        patectgan      neural net   national2019
# 115               sdv             tvae      neural net         tx2019
# 58           sdcmicro       kanonymity             sdc   national2019
# 117               sdv             tvae      neural net         tx2019
# 70           sdcmicro       kanonymity             sdc         tx2019
# 102               sdv           fastml      neural net         tx2019
# 98                sdv            ctgan      neural net         tx2019
# 176  smartnoise-synth         pacsynth  query matching         tx2019
# 243         synthcity           adsgan      neural net   national2019
# 286         synthcity          pategan      neural net         tx2019
# 288         synthcity          pategan      neural net         tx2019
# 71           sdcmicro       kanonymity             sdc         tx2019
# 57           sdcmicro       kanonymity             sdc         ma2019
# 165  smartnoise-synth         pacsynth  query matching         ma2019
# 163  smartnoise-synth         pacsynth  query matching         ma2019
# 175  smartnoise-synth         pacsynth  query matching         tx2019
# 162  smartnoise-synth         pacsynth  query matching         ma2019
# 67           sdcmicro       kanonymity             sdc         tx2019
# 100               sdv           fastml      neural net   national2019
# 101               sdv           fastml      neural net   national2019
# 250         synthcity           adsgan      neural net         tx2019
# 265         synthcity          pategan      neural net         ma2019
# 99                sdv           fastml      neural net         ma2019
# 274         synthcity          pategan      neural net   national2019
#
#     privacy category  epsilon                      feature set name  \
# 263               dp      1.0                          all-features
# 192               dp      1.0                       simple-features
# 209               dp      1.0                        family-focused
# 213               dp      1.0                       simple-features
# 191               dp      1.0                      industry-focused
# 183               dp      1.0                   demographic-focused
# 188               dp      1.0                        family-focused
# 204               dp      1.0                   demographic-focused
# 212               dp      1.0                      industry-focused
# 299               dp     10.0                      industry-focused
# 105           non_dp      NaN                        family-focused
# 296               dp     10.0                   demographic-focused
# 297               dp      1.0                        family-focused
# 320               dp      1.0  demographic-focused-except-AGEP-DEYE
# 201               dp      1.0                       simple-features
# 289               dp      1.0                   demographic-focused
# 321               dp      2.0  demographic-focused-except-AGEP-DEYE
# 47                dp      1.0                   demographic-focused
# 42                dp      1.0                   demographic-focused
# 61               sdc      NaN                        family-focused
# 245           non_dp      NaN                        family-focused
# 85            non_dp      NaN                    custom-features-23
# 269               dp      1.0                        family-focused
# 246           non_dp      NaN                      industry-focused
# 170               dp      5.0                        family-focused
# 203               dp      5.0                          all-features
# 62               sdc      NaN                        family-focused
# 168               dp      1.0                   demographic-focused
# 291               dp      1.0                        family-focused
# 322               dp      4.0  demographic-focused-except-AGEP-DEYE
# 194               dp      5.0                          all-features
# 171               dp     10.0                        family-focused
# 293               dp     10.0                      industry-focused
# 276               dp      1.0                   demographic-focused
# 295               dp      1.0                   demographic-focused
# 174               dp      1.0                      industry-focused
# 305               dp     10.0                      industry-focused
# 182               dp      5.0                          all-features
# 104           non_dp      NaN                        family-focused
# 242           non_dp      NaN                          all-features
# 275               dp     10.0                   demographic-focused
# 66               sdc      NaN                      industry-focused
# 266               dp     10.0                   demographic-focused
# 69               sdc      NaN                        family-focused
# 72               sdc      NaN                      industry-focused
# 180               dp      1.0                      industry-focused
# 178               dp      5.0                        family-focused
# 271               dp      1.0                      industry-focused
# 110           non_dp      NaN                          all-features
# 177               dp     10.0                        family-focused
# 282               dp      1.0                          all-features
# 197               dp      5.0                        family-focused
# 115           non_dp      NaN                          all-features
# 58               sdc      NaN                   demographic-focused
# 117           non_dp      NaN                        family-focused
# 70               sdc      NaN                        family-focused
# 102           non_dp      NaN                    custom-features-23
# 98            non_dp      NaN                          all-features
# 176               dp      5.0                   demographic-focused
# 243           non_dp      NaN                          all-features
# 286               dp      1.0                        family-focused
# 288               dp      1.0                      industry-focused
# 71               sdc      NaN                      industry-focused
# 57               sdc      NaN                      industry-focused
# 165               dp      1.0                      industry-focused
# 163               dp      5.0                        family-focused
# 175               dp     10.0                   demographic-focused
# 162               dp     10.0                        family-focused
# 67               sdc      NaN                   demographic-focused
# 100           non_dp      NaN                    custom-features-23
# 101           non_dp      NaN                   demographic-focused
# 250           non_dp      NaN                      industry-focused
# 265               dp      1.0                          all-features
# 99            non_dp      NaN                    custom-features-23
# 274               dp      1.0                          all-features
#
#      race_edit_distance_percent
# 263                      175.66
# 192                      147.26
# 209                      142.54
# 213                      142.48
# 191                      139.01
# 183                      136.97
# 188                      136.65
# 204                      135.06
# 212                      128.87
# 299                      119.55
# 105                      119.28
# 296                      118.85
# 297                      114.95
# 320                      113.01
# 201                      111.86
# 289                      106.26
# 321                      101.44
# 47                       101.00
# 42                       100.13
# 61                        72.15
# 245                       69.09
# 85                        68.43
# 269                       67.07
# 246                       62.61
# 170                       62.36
# 203                       58.17
# 62                        57.15
# 168                       56.21
# 291                       52.19
# 322                       51.18
# 194                       49.15
# 171                       45.55
# 293                       44.62
# 276                       43.51
# 295                       43.08
# 174                       42.76
# 305                       40.58
# 182                       39.43
# 104                       37.67
# 242                       35.27
# 275                       33.52
# 66                        32.01
# 266                       31.91
# 69                        31.16
# 72                        31.16
# 180                       31.16
# 178                       31.16
# 271                       31.05
# 110                       30.55
# 177                       30.34
# 282                       30.21
# 197                       30.08
# 115                       29.41
# 58                        29.36
# 117                       29.15
# 70                        29.03
# 102                       28.89
# 98                        28.31
# 176                       26.72
# 243                       26.39
# 286                       26.02
# 288                       25.94
# 71                        25.74
# 57                        25.57
# 165                       25.57
# 163                       25.57
# 175                       25.28
# 162                       24.66
# 67                        24.58
# 100                       24.47
# 101                       24.47
# 250                       24.26
# 265                       23.89
# 99                        23.55
# 274                       22.96

# %% [markdown]
# ### 2.1 Best performing 75 samples.

# %%
# See the random 100 records from index dataframe and
# the new column race_edit_distance which we just added to the
# index dataframe

# Set pandas display max rows option to display more
# dataframe rows in the cell output
pd.set_option('display.max_rows', 151)
# Name of the columns to display in the selected data samples
columns_to_show = [LIBRARY_NAME, ALGORITHM_NAME, ALGORITHM_TYPE, TARGET_DATASET,
                   PRIVACY_CATEGORY, EPSILON, FEATURE_SET_NAME, RACE_EDIT_DISTANCE_PERCENT]

# Sort the samples by race_edit_distance
idx_df = idx_df.sort_values(by=RACE_EDIT_DISTANCE_PERCENT, ascending=True)
# Show 75 best performing samples in the index dataframe
idx_sample_df = idx_df[columns_to_show].head(75)
# Show samples dataframe
idx_sample_df
# Out:
#          library name    algorithm name  algorithm type target dataset  \
# 43          rsynthpop            catall       histogram   national2019
# 132  smartnoise-synth               mst      stat model   national2019
# 139  smartnoise-synth               mst      stat model   national2019
# 140  smartnoise-synth               mst      stat model   national2019
# 134  smartnoise-synth               mst      stat model   national2019
# 135  smartnoise-synth               mst      stat model   national2019
# 137  smartnoise-synth               mst      stat model   national2019
# 319            tumult            DPHist       histogram   national2019
# 150  smartnoise-synth               mst      stat model         tx2019
# 128  smartnoise-synth               mst      stat model         ma2019
# 141  smartnoise-synth               mst      stat model   national2019
# 146  smartnoise-synth               mst      stat model         tx2019
# 126  smartnoise-synth               mst      stat model         ma2019
# 151  smartnoise-synth               mst      stat model         tx2019
# 122  smartnoise-synth               mst      stat model         ma2019
# 222  subsample_40pcnt  subsample_40pcnt             sdc         ma2019
# 131  smartnoise-synth               mst      stat model   national2019
# 28          rsynthpop              cart      stat model         ma2019
# 80           sdcmicro              pram             sdc   national2019
# 77           sdcmicro              pram             sdc   national2019
# 148  smartnoise-synth               mst      stat model         tx2019
# 123  smartnoise-synth               mst      stat model         ma2019
# 74           sdcmicro              pram             sdc         ma2019
# 138  smartnoise-synth               mst      stat model   national2019
# 76           sdcmicro              pram             sdc   national2019
# 147  smartnoise-synth               mst      stat model         tx2019
# 120  smartnoise-synth               mst      stat model         ma2019
# 81           sdcmicro              pram             sdc   national2019
# 51          rsynthpop         ipf_NonDP  query matching   national2019
# 32          rsynthpop              cart      stat model   national2019
# 304         synthcity         privbayes      stat model         tx2019
# 144  smartnoise-synth               mst      stat model         tx2019
# 224  subsample_40pcnt  subsample_40pcnt             sdc   national2019
# 156  smartnoise-synth              mwem  query matching   national2019
# 9          Genetic SD        Genetic SD  query matching   national2019
# 8          Genetic SD        Genetic SD  query matching   national2019
# 225  subsample_40pcnt  subsample_40pcnt             sdc   national2019
# 27          rsynthpop              cart      stat model         ma2019
# 292         synthcity         privbayes      stat model         ma2019
# 294         synthcity         privbayes      stat model         ma2019
# 44          rsynthpop            catall       histogram   national2019
# 130  smartnoise-synth               mst      stat model         ma2019
# 11         Genetic SD        Genetic SD  query matching   national2019
# 75           sdcmicro              pram             sdc         ma2019
# 252         synthcity  bayesian_network      stat model         ma2019
# 30          rsynthpop              cart      stat model         ma2019
# 38          rsynthpop              cart      stat model         tx2019
# 251         synthcity  bayesian_network      stat model         ma2019
# 290         synthcity         privbayes      stat model         ma2019
# 254         synthcity  bayesian_network      stat model         ma2019
# 258         synthcity  bayesian_network      stat model   national2019
# 73           sdcmicro              pram             sdc         ma2019
# 25        MostlyAI SD       MostlyAI SD      neural net         tx2019
# 124  smartnoise-synth               mst      stat model         ma2019
# 157  smartnoise-synth              mwem  query matching   national2019
# 253         synthcity  bayesian_network      stat model         ma2019
# 262         synthcity  bayesian_network      stat model         tx2019
# 306         synthcity         privbayes      stat model         tx2019
# 82           sdcmicro              pram             sdc         tx2019
# 303         synthcity         privbayes      stat model         tx2019
# 31          rsynthpop              cart      stat model         ma2019
# 119  smartnoise-synth               mst      stat model         ma2019
# 230  subsample_40pcnt  subsample_40pcnt             sdc         tx2019
# 232  subsample_40pcnt  subsample_40pcnt             sdc         tx2019
# 226  subsample_40pcnt  subsample_40pcnt             sdc   national2019
# 301         synthcity         privbayes      stat model         tx2019
# 83           sdcmicro              pram             sdc         tx2019
# 48          rsynthpop      catall_NonDP       histogram   national2019
# 259         synthcity  bayesian_network      stat model         tx2019
# 298         synthcity         privbayes      stat model   national2019
# 260         synthcity  bayesian_network      stat model         tx2019
# 256         synthcity  bayesian_network      stat model   national2019
# 37          rsynthpop              cart      stat model         tx2019
# 261         synthcity  bayesian_network      stat model         tx2019
# 255         synthcity  bayesian_network      stat model   national2019
#
#     privacy category  epsilon                      feature set name  \
# 43                dp    100.0                   demographic-focused
# 132               dp     10.0                   demographic-focused
# 139               dp      5.0                      industry-focused
# 140               dp     10.0                      industry-focused
# 134               dp      5.0                   demographic-focused
# 135               dp      5.0                        family-focused
# 137               dp     10.0                        family-focused
# 319               dp     10.0  demographic-focused-except-AGEP-DEYE
# 150               dp      5.0                      industry-focused
# 128               dp     10.0                      industry-focused
# 141               dp     10.0                       simple-features
# 146               dp     10.0                   demographic-focused
# 126               dp      5.0                      industry-focused
# 151               dp     10.0                      industry-focused
# 122               dp     10.0                   demographic-focused
# 222              sdc      NaN                      industry-focused
# 131               dp      5.0                          all-features
# 28            non_dp      NaN                   demographic-focused
# 80               sdc      NaN                      industry-focused
# 77               sdc      NaN                   demographic-focused
# 148               dp      5.0                        family-focused
# 123               dp     10.0                        family-focused
# 74               sdc      NaN                        family-focused
# 138               dp      1.0                      industry-focused
# 76               sdc      NaN                   demographic-focused
# 147               dp     10.0                        family-focused
# 120               dp      5.0                   demographic-focused
# 81               sdc      NaN                      industry-focused
# 51            non_dp      NaN                   demographic-focused
# 32            non_dp      NaN                    custom-features-21
# 304               dp     10.0                        family-focused
# 144               dp      5.0                   demographic-focused
# 224              sdc      NaN                          all-features
# 156               dp     10.0       demographic-focused-except-DEYE
# 9                 dp     10.0                       simple-features
# 8                 dp     10.0                          all-features
# 225              sdc      NaN                   demographic-focused
# 27            non_dp      NaN                    custom-features-21
# 292               dp     10.0                        family-focused
# 294               dp      1.0                      industry-focused
# 44                dp    100.0                   demographic-focused
# 130               dp     10.0                       simple-features
# 11                dp     10.0                       simple-features
# 75               sdc      NaN                      industry-focused
# 252           non_dp      NaN                   demographic-focused
# 30            non_dp      NaN                        family-focused
# 38            non_dp      NaN                   demographic-focused
# 251           non_dp      NaN                          all-features
# 290               dp     10.0                   demographic-focused
# 254           non_dp      NaN                      industry-focused
# 258           non_dp      NaN                      industry-focused
# 73               sdc      NaN                   demographic-focused
# 25            non_dp      NaN                          all-features
# 124               dp      5.0                        family-focused
# 157               dp     10.0             detailed-industry-focused
# 253           non_dp      NaN                        family-focused
# 262           non_dp      NaN                      industry-focused
# 306               dp      1.0                      industry-focused
# 82               sdc      NaN                   demographic-focused
# 303               dp      1.0                        family-focused
# 31            non_dp      NaN                      industry-focused
# 119               dp      5.0                          all-features
# 230              sdc      NaN                   demographic-focused
# 232              sdc      NaN                      industry-focused
# 226              sdc      NaN                        family-focused
# 301               dp      1.0                   demographic-focused
# 83               sdc      NaN                        family-focused
# 48            non_dp      NaN                   demographic-focused
# 259           non_dp      NaN                          all-features
# 298               dp     10.0                        family-focused
# 260           non_dp      NaN                   demographic-focused
# 256           non_dp      NaN                   demographic-focused
# 37            non_dp      NaN                    custom-features-21
# 261           non_dp      NaN                        family-focused
# 255           non_dp      NaN                          all-features
#
#      race_edit_distance_percent
# 43                         0.00
# 132                        0.05
# 139                        0.07
# 140                        0.08
# 134                        0.13
# 135                        0.15
# 137                        0.15
# 319                        0.24
# 150                        0.26
# 128                        0.26
# 141                        0.29
# 146                        0.30
# 126                        0.31
# 151                        0.34
# 122                        0.37
# 222                        0.40
# 131                        0.43
# 28                         0.45
# 80                         0.46
# 77                         0.46
# 148                        0.47
# 123                        0.47
# 74                         0.47
# 138                        0.50
# 76                         0.52
# 147                        0.52
# 120                        0.52
# 81                         0.52
# 51                         0.54
# 32                         0.57
# 304                        0.58
# 144                        0.58
# 224                        0.61
# 156                        0.61
# 9                          0.61
# 8                          0.61
# 225                        0.62
# 27                         0.63
# 292                        0.63
# 294                        0.63
# 44                         0.65
# 130                        0.65
# 11                         0.68
# 75                         0.68
# 252                        0.68
# 30                         0.71
# 38                         0.73
# 251                        0.73
# 290                        0.76
# 254                        0.76
# 258                        0.76
# 73                         0.76
# 25                         0.78
# 124                        0.79
# 157                        0.79
# 253                        0.79
# 262                        0.86
# 306                        0.86
# 82                         0.86
# 303                        0.86
# 31                         0.89
# 119                        0.89
# 230                        0.91
# 232                        0.91
# 226                        0.93
# 301                        0.95
# 83                         0.95
# 48                         0.95
# 259                        0.97
# 298                        0.97
# 260                        0.97
# 256                        0.98
# 37                         0.99
# 261                        0.99
# 255                        0.99
